# %% [markdown]
# <a href="https://colab.research.google.com/github/DEVIPARVATHIMANYAM/fmml-assignment-/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-15 15:54:37--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   163MB/s    in 0.4s
#
# 2023-06-15 15:54:38 (163 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22601  1702.05777v5  Background: Statistical mechanics results (Dau...  stat
# 37761  1803.00119v1  In partially observed environments, it can be ...    cs
# 2578   1606.03860v2  Probabilistic models analyze data by relying o...  stat
# 18407   1005.2815v1  We discuss how to use a Genetic Regulatory Net...    cs
# 6864   1706.10031v1  We propose a new neural sequence model trainin...  stat
# ...             ...                                                ...   ...
# 12992   1210.3456v2  MicroRNAs (miRNAs) are small RNA molecules com...  stat
# 4910   1701.04113v1  The combinatorial explosion that plagues plann...    cs
# 7976   1706.00648v1  We overview dataflow matrix machines as a Turi...    cs
# 37293  1702.07134v2  Bipartite matching, where agents on one side o...    cs
# 27940  1705.00938v2  Training deep fully convolutional neural netwo...    cs
#
#                                                    title  year  \
# 22601  Exponentially vanishing sub-optimal local mini...  2017
# 37761  Integrating Human-Provided Information Into Be...  2018
# 2578   Robust Probabilistic Modeling with Bayesian Da...  2016
# 18407                   Evolving Genes to Balance a Pole  2010
# 6864   Neural Sequence Model Training via $α$-diverge...  2017
# ...                                                  ...   ...
# 12992  Bayesian Analysis for miRNA and mRNA Interacti...  2012
# 4910   Near Optimal Behavior via Approximate State Ab...  2017
# 7976   Dataflow Matrix Machines as a Model of Computa...  2017
# 37293              Diverse Weighted Bipartite b-Matching  2017
# 27940  Error Corrective Boosting for Learning Fully C...  2017
#
#                                                 keywords
# 22601  [background, statistical, mechanics, choromans...
# 37761  [partially, environments, declarative, informa...
# 2578   [probabilistic, assumptions, deviations, assum...
# 18407  [regulatory, evolutionary, representation, rei...
# 6864   [objective, divergence, demonstrate, objective...
# ...                                                  ...
# 12992  [micrornas, molecules, important, regulatory, ...
# 4910   [combinatorial, explosion, reinforcement, algo...
# 7976   [generalization, recurrent, programming, numer...
# 37293  [bipartite, classical, economics, widespread, ...
# 27940  [convolutional, segmentation, unlabeled, avail...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22601    [background, statistical, mechanics, choromans...
# 37761    [partially, environments, declarative, informa...
# 2578     [probabilistic, assumptions, deviations, assum...
# 18407    [regulatory, evolutionary, representation, rei...
# 6864     [objective, divergence, demonstrate, objective...
#                                ...
# 9114     [multilingual, classification, documents, diff...
# 38115    [applications, technology, analyzing, historic...
# 36273    [introduce, algorithms, quantified, heuristics...
# 11223    [decompositions, applications, complexity, alg...
# 16600    [paraphrase, identification, questions, annota...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8818 words.
# Out of those 4586 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3a6ec7c8-01e6-473d-9b59-0f53bdce9e5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a6ec7c8-01e6-473d-9b59-0f53bdce9e5c")) {                    Plotly.newPlot(                        "3a6ec7c8-01e6-473d-9b59-0f53bdce9e5c",                        [{"x":["assumptions","dimensions","statistical","quadratic","containing","differentiable","comparison","vanishing","piecewise","dimension","multilayer","realistic","numerically","datapoints","classification","unrealistic","background","exponentially","probability","demonstrate","mechanics","guarantees","factoring","dynamically","observable","improvements","selecting","observations","integrating","efficiency","computational","presented","knowledge","experimentally","partially","gridworld","representation","declarative","locations","correlated","separating","inference","environments","factorization","combining","continuous","appropriate","combination","information","efficient","significant","inferring","protection","undermine","prediction","probabilistic","variables","different","likelihood","deviations","misspecification","systematically","movielens","reweighting","practical","structure","predictive","observation","generalize","evolutionary","regulatory","artificial","performance","connecting","balancing","reinforcement","divergence","minimization","functions","outperforms","translation","considered","objective","generalizes","gradients","minimizing","corresponds","experimental","consistent","conventional","similarity","collection","aggregating","advantage","experiments","persistent","traditional","multidimensional","embeddings","manufacturability","framework","duplicate","deconvolution","relationships","technique","contextual","described","theoretical","therefore","validation","independently","dependency","advantages","empirical","heterogeneous","clustering","categorical","biomedical","solutions","consisting","variational","depression","distributions","nonparametric","inferences","multinomial","typically","synthetic","computation","simultaneously","applicable","distribution","recovering","dimensional","structures","available","numerical","approximation","composite","techniques","composition","generally","automatic","constrained","configuration","applications","addressed","specification","traditionally","languages","viability","weaknesses","abstraction","organized","attentional","interpretation","processes","characterize","electrocardiogram","explaining","approaches","deductive","abductive","mechanism","appearing","reasoning","strengths","implementing","underlying","assumption","hierarchy","representative","application","algorithms","hypothesis","highlight","monotonic","explanation","hypothesize","capturing","competitive","generative","amortized","successful","variability","maximizing","annealing","recurrent","posterior","architectures","augmented","benchmarks","interpretable","conceptually","alternative","associated","condition","sequential","autoregressive","performed"],"y":[55,48,159,34,51,21,113,9,10,63,15,64,8,1,500,1,79,16,176,560,8,48,3,26,24,128,40,91,32,157,309,164,351,53,52,1,370,11,38,34,12,225,93,46,96,107,83,137,688,415,249,33,11,1,244,150,126,740,75,4,0,19,1,2,152,351,55,50,53,89,2,138,888,9,13,126,18,60,209,251,115,116,147,34,34,51,20,378,71,114,146,74,17,80,593,5,189,12,63,1,559,3,7,73,211,41,63,188,157,47,38,42,97,181,31,153,10,26,147,56,43,3,106,8,19,8,108,144,151,124,58,201,22,197,159,284,103,133,19,383,37,91,195,57,31,426,34,19,26,106,7,16,26,16,9,60,111,48,2,14,426,3,4,130,11,133,19,30,124,81,40,30,249,610,51,34,11,20,10,46,106,127,2,75,28,27,8,145,44,106,52,105,33,9,92,120,51,75,6,137],"type":"bar"},{"x":["assumptions","dimensions","statistical","quadratic","containing" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4586,), (4586, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7758333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Human</span> <span style=''>and</span> <span style=''>Machine</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>Judgements</span> <span style=''>for</span> <span style=''>Russian</span> <span style=''>Semantic</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666667);'>Relatedness</span> <br/><br/><span style=''>Semantic</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666667);'>relatedness</span> <span style=''>of</span> <span style=''>terms</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represents</span> <span style='background-color:rgba(0, 255, 0, 0.3394495412844037);'>similarity</span> <span style=''>of</span> <span style=''>meaning</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3622291021671826);'>numerical</span> <span style=''>score</span> <span style=''>On</span> <span style=''>the</span> <span style=''>one</span> <span style=''>hand</span> <span style=''>humans</span> <span style=''>easily</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285714);'>judgments</span> <span style=''>about</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666667);'>relatedness</span> <span style=''>On</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style=''>this</span> <span style=''>kind</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.30550284629981034);'>information</span> <span style=''>is</span> <span style=''>useful</span> <span style=''>in</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.4444444444444446);'>processing</span> <span style=''>systems</span> <span style=''>While</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666667);'>relatedness</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.4444444444444446);'>extensively</span> <span style=''>studied</span> <span style=''>for</span> <span style=''>English</span> <span style=''>using</span> <span style=''>numerous</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.5750000000000001);'>resources</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>associative</span> <span style=''>norms</span> <span style=''>human</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285714);'>judgments</span> <span style=''>and</span> <span style=''>datasets</span> <span style='background-color:rgba(0, 255, 0, 0.3210332103321034);'>generated</span> <span style=''>from</span> <span style=''>lexical</span> <span style='background-color:rgba(0, 255, 0, 0.3972602739726028);'>databases</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.4931880108991825);'>evaluation</span> <span style='background-color:rgba(0, 255, 0, 0.5750000000000001);'>resources</span> <span style=''>of</span> <span style=''>this</span> <span style=''>kind</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>for</span> <span style=''>Russian</span> <span style=''>to</span> <span style=''>date</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contribution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>addresses</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>We</span> <span style=''>present</span> <span style=''>five</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.5750000000000001);'>resources</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3237924865831843);'>different</span> <span style=''>scale</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Randomized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Coefficient</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Randomized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Coefficient</span> <span style=''>(RDC)</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>of</span> <span style=''>non</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>between</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Hirschfeld</span> <span style=''>Gebelein</span> <span style=''>Renyi</span> <span style=''>Maximum</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Correlation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Coefficient</span> <span style=''>RDC</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style=''>of</span> <span style=''>random</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>copula</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformations</span> <span style=''>has</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>and</span> <span style=''>is</span> <span style=''>easy</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>just</span> <span style=''>five</span> <span style=''>lines</span> <span style=''>of</span> <span style=''>R</span> <span style=''>code</span> <span style=''>included</span> <span style=''>at</span> <span style=''>the</span> <span style=''>end</span> <span style=''>of</span> <span style=''>the</span> <span style=''>paper</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Illuminant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Ensembles</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.7310924369747898);'>Multivariate</span> <span style='background-color:rgba(255, 0, 0, 0.48333333333333334);'>Regression</span> <span style=''>Trees</span> <br/><br/><span style=''>White</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>balancing</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>step</span> <span style=''>in</span> <span style=''>the</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.4444444444444446);'>processing</span> <span style=''>pipeline</span> <span style=''>The</span> <span style=''>process</span> <span style=''>involves</span> <span style='background-color:rgba(255, 0, 0, 0.3731343283582089);'>estimating</span> <span style=''>the</span> <span style=''>chromaticity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>illuminant</span> <span style=''>or</span> <span style=''>light</span> <span style=''>source</span> <span style=''>and</span> <span style=''>using</span> <span style=''>the</span> <span style=''>estimate</span> <span style=''>to</span> <span style=''>correct</span> <span style=''>the</span> <span style=''>image</span> <span style=''>to</span> <span style=''>remove</span> <span style=''>any</span> <span style=''>color</span> <span style=''>cast</span> <span style=''>Given</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>there</span> <span style=''>has</span> <span style=''>been</span> <span style=''>much</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>on</span> <span style=''>illuminant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>Recently</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ensembles</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.5862068965517241);'>univariate</span> <span style='background-color:rgba(255, 0, 0, 0.48333333333333334);'>regression</span> <span style=''>trees</span> <span style=''>that</span> <span style=''>are</span> <span style=''>fit</span> <span style=''>using</span> <span style=''>the</span> <span style=''>squared</span> <span style=''>error</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>has</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>and</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>give</span> <span style='background-color:rgba(0, 255, 0, 0.43396226415094347);'>excellent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>simpler</span> <span style=''>and</span> <span style=''>more</span> <span style=''>accurate</span> <span style=''>ensemble</span> <span style=''>model</span> <span style=''>can</span> <span style=''>be</span> <span style=''>learned</span> <span style=''>by</span> <span style=''>(i)</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.7310924369747898);'>multivariate</span> <span style='background-color:rgba(255, 0, 0, 0.48333333333333334);'>regression</span> <span style=''>trees</span> <span style=''>to</span> <span style=''>take</span> <span style=''>into</span> <span style=''>account</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Mixtures</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bernoulli</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Templates</span> <span style=''>by</span> <span style=''>Two</span> <span style=''>Round</span> <span style=''>EM</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Performance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Guarantee</span> <br/><br/><span style=''>Dasgupta</span> <span style=''>and</span> <span style=''>Shulman</span> <span style=''>showed</span> <span style=''>that</span> <span style=''>a</span> <span style=''>two</span> <span style=''>round</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>the</span> <span style=''>EM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>can</span> <span style=''>learn</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>with</span> <span style=''>near</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>if</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>are</span> <span style=''>well</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separated</span> <span style=''>and</span> <span style=''>if</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficiently</span> <span style=''>high</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>their</span> <span style=''>theory</span> <span style=''>to</span> <span style=''>learning</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bernoulli</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>templates</span> <span style=''>Each</span> <span style=''>template</span> <span style=''>is</span> <span style=''>a</span> <span style=''>binary</span> <span style=''>vector</span> <span style=''>and</span> <span style=''>a</span> <span style=''>template</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generates</span> <span style=''>examples</span> <span style=''>by</span> <span style=''>randomly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>switching</span> <span style=''>its</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style=''>with</span> <span style=''>a</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>In</span> <span style=''>computer</span> <span style=''>vision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>a</span> <span style=''>binary</span> <span style=''>vector</span> <span style=''>is</span> <span style=''>a</span> <span style=''>feature</span> <span style=''>map</span> <span style=''>of</span> <span style=''>an</span> <span style=''>image</span> <span style=''>where</span> <span style=''>each</span> <span style=''>binary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indicates ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10138248847926268)
# 	experimental (0.13399503722084366)
# 	challenging (0.0999645515774548)
# 	evaluation (0.09712867777383906)
# 	information (0.24388514711095358)
# 	representation (0.13115916341722794)
# 	different (0.2623183268344559)
# 	recognition (0.12548741580999645)
# 	detection (0.12690535271180434)
# 	convolutional (0.12655086848635236)
#
# Some Statistics words are:
# 	variational (0.09903991915108641)
# 	theoretical (0.15765538150581102)
# 	estimation (0.16978271854471955)
# 	algorithm (0.3799898938858009)
# 	variables (0.1435068216270844)
# 	statistical (0.16523496715512886)
# 	dimensional (0.1839312784234462)
# 	distribution (0.1864578069732188)
# 	inference (0.19807983830217282)
# 	regression (0.17988883274381)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3c80588c-304d-4123-be8d-6dc271c830fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c80588c-304d-4123-be8d-6dc271c830fc")) {                    Plotly.newPlot(                        "3c80588c-304d-4123-be8d-6dc271c830fc",                        [{"x":["assumptions","dimensions","statistical","quadratic","containing","differentiable","comparison","vanishing","piecewise","dimension","multilayer","realistic","numerically","datapoints","classification","unrealistic","background","exponentially","probability","demonstrate","mechanics","guarantees","factoring","dynamically","observable","improvements","selecting","observations","integrating","efficiency","computational","presented","knowledge","experimentally","partially","gridworld","representation","declarative","locations","correlated","separating","inference","environments","factorization","combining","continuous","appropriate","combination","information","efficient","significant","inferring","protection","undermine","prediction","probabilistic","variables","different","likelihood","deviations","misspecification","systematically","movielens","reweighting","practical","structure","predictive","observation","generalize","evolutionary","regulatory","artificial","performance","connecting","balancing","reinforcement","divergence","minimization","functions","outperforms","translation","considered","objective","generalizes","gradients","minimizing","corresponds","experimental","consistent","conventional","similarity","collection","aggregating","advantage","experiments","persistent","traditional","multidimensional","embeddings","manufacturability","framework","duplicate","deconvolution","relationships","technique","contextual","described","theoretical","therefore","validation","independently","dependency","advantages","empirical","heterogeneous","clustering","categorical","biomedical","solutions","consisting","variational","depression","distributions","nonparametric","inferences","multinomial","typically","synthetic","computation","simultaneously","applicable","distribution","recovering","dimensional","structures","available","numerical","approximation","composite","techniques","composition","generally","automatic","constrained","configuration","applications","addressed","specification","traditionally","languages","viability","weaknesses","abstraction","organized","attentional","interpretation","processes","characterize","electrocardiogram","explaining","approaches","deductive","abductive","mechanism","appearing","reasoning","strengths","implementing","underlying","assumption","hierarchy","representative","application","algorithms","hypothesis","highlight","monotonic","explanation","hypothesize","capturing","competitive","generative","amortized","successful","variability","maximizing","annealing","recurrent","posterior","architectures","augmented","benchmarks","interpretable","conceptually","alternative","associated","condition","sequential","autoregressive","performed","independent","reconstruct","stochastic","approximate","auxiliary","evolution","represent","transition","statement","comprehensive","furthermore","simplicity","resources","demonstrated","outperform","connections","introduces","scenarios","proposals","appearance","compactness","pedestrians","accurately","extensive","aggregation","meaningful","representations","respectively","detection","conditions","challenging","unavailable","occlusions","characteristics","superiority","encourages","individual","challenge","particular","variations","appearances","presumably","phenomena","wikipedia","substantial","important","differences","incapable","classifiers","representing","political","evaluation","following","celebrities","sociological ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	misspecification
# 	dendrogram
# 	eliciting
# 	individualized
# 	barycenters
# 	blockmodel
# 	integrations
# 	cooccurence
# 	uncorrupted
# 	mislabeled
# 	immigration
# 	covariates
# 	cytometry
# 	dominates
# 	similitude
# 	discarding
# 	selectors
# 	suppresses
# 	trilinear
# 	itinerary
# Some words which never appear in Statistics papers:
# 	declarative
# 	deductive
# 	occlusions
# 	appearances
# 	celebrities
# 	sociological
# 	unanimity
# 	unanimous
# 	truthfully
# 	intersecting
# 	instantly
# 	traveling
# 	anonymized
# 	genotypes
# 	epistasis
# 	intentions
# 	periodical
# 	constancy
# 	argumentation
# 	argumentative

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0491523356506895e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7291666666666666
